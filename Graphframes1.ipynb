# %%
from functools import reduce
from pyspark.sql.functions import col, lit, when
from graphframes import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ZipImportError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-420574695540941&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansigreen">from</span> functools <span class="ansigreen">import</span> reduce<span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> <span class="ansigreen">from</span> pyspark<span class="ansiyellow">.</span>sql<span class="ansiyellow">.</span>functions <span class="ansigreen">import</span> col<span class="ansiyellow">,</span> lit<span class="ansiyellow">,</span> when<span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 3</span><span class="ansiyellow"> </span><span class="ansigreen">from</span> graphframes <span class="ansigreen">import</span> <span class="ansiyellow">*</span><span class="ansiyellow"></span>
#
# <span class="ansired">ZipImportError</span>: can&apos;t find module &apos;graphframes&apos;</div>

# %%
text = 'geeks for geeks'
print(text.split(', '))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;geeks for geeks&apos;]
# </div>

# %%
word = 'CatBatSatFatOr'
print([word[i:i+3] for i in range(0, len(word), 3)])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;Cat&apos;, &apos;Bat&apos;, &apos;Sat&apos;, &apos;Fat&apos;, &apos;Or&apos;]
# </div>

# %%
print("Junaid \n\n Effendi")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Junaid
#
#  Effendi
# </div>
