# %%
def squ(s):
    return s*s
udf_regis = spark.udf.register('squ1',squ,LongType())

spark.range(1,5).registerTempTable('test')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select id,squ1(id) from test;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>squ1(id)</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr><tr><td>2</td><td>4</td></tr><tr><td>3</td><td>9</td></tr><tr><td>4</td><td>16</td></tr></tbody></table></div>

# %%
'''
This Options are tryoing for spark SQL .
Options -01 : 
- Import the Raw Functions name 
  Undefined function: 'squ'. This function is neither a registered temporary function nor a permanent function registered in the database 'default'.; line 1 pos 10

Options - 02 :
- Import the Assigned Variable :

Error in SQL statement: AnalysisException: Undefined function: 'udf_regis'. This function is neither a registered temporary function nor a permanent function registered in the database 'default'.; line 1 pos 10

Options - 03:

Register with the new function name , need to be import - Working Fine.
'''

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *
from pyspark import HiveContext
from pyspark import SQLContext
def red(x):
    return x*x
#reg_udf = udf(sq,LongType())
reg_udf = spark.udf.register('Green',red)
spark.range(1,5).registerTempTable('test')

df = spark.table('test')

display(df.select('id',reg_udf('id')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Green(id)</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr><tr><td>2</td><td>4</td></tr><tr><td>3</td><td>9</td></tr><tr><td>4</td><td>16</td></tr></tbody></table></div>

# %%
'''
Working with Dataframe :

Options -1: 
Assigned variable is working fine . 

Option -2 

'''

# %%
from pyspark.sql.functions import udf 
def squard_udf(s):
    return s*s
df = spark.table('test')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import udf
@udf
def squared_udf(x):
    return x*x
df = spark.table('test')
display(df.select('id',squared_udf('id')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>squared_udf(id)</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr><tr><td>2</td><td>4</td></tr><tr><td>3</td><td>9</td></tr><tr><td>4</td><td>16</td></tr></tbody></table></div>
