# %%
from pyspark import SQLContext
from pyspark import HiveContext
a = sc.accumulator(10)
data = [10,20]
rdd = sc.parallelize(data)
def f(x):
    global a
    a += x
rdd.foreach(f)

a.value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">52</span><span class="ansired">]: </span>40
# </div>

# %%
a= sc.accumulator(0)
data = [10,20,10,10,10,10]
def f(x):
    global a
    if x == 10:
       a += 1
rdd = sc.parallelize(data)
rdd.foreach(f)
a.value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">59</span><span class="ansired">]: </span>5
# </div>

# %%
from pyspark import SQLContext
from pyspark import HiveContext 
data = (['karthikeyan','navaneethan','karthikeyan','karthikeyan'])
a = sc.accumulator(1)
rdd = sc.parallelize(data)
def f(x):
    global a
    if x == 'karthikeyan':
       a+= 1
rdd.foreach(f)
a.value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">75</span><span class="ansired">]: </span>4
# </div>

# %%
from pyspark import HiveContext
from pyspark import SQLContext 
data = [10,20,30,10,10,10]
a = sc.accumulator(0)
rdd = sc.parallelize(data)
def f(x):
  global a
  if x == 10:
     a += 1
print(a)
rdd.foreach(f)
print(a)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# 4
# </div>
