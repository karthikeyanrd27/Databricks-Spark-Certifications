# %%
#To get the value and index of the list 
a = [1,2,3,5,6]
print(a)
for x,y in enumerate(a):
    if y ==3:
       for j in a[y:]:
           print (j)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[1, 2, 3, 5, 6]
# 5
# 6
# </div>

# %%
#Understanding slice notation:
print(a[:])
print(a[1:])
print(a[1:2])
print(a[:2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[1, 2, 3, 5, 6]
# [2, 3, 5, 6]
# [2]
# [1, 2]
# </div>

# %%
#Ex01: write a program which is divide by 7 and not divide by 5 
l = []
for i in range(1,100):
    if (i%7 ==0) &(i%5!=0):
       l.append(str(i))
print (l)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;7&apos;, &apos;14&apos;, &apos;21&apos;, &apos;28&apos;, &apos;42&apos;, &apos;49&apos;, &apos;56&apos;, &apos;63&apos;, &apos;77&apos;, &apos;84&apos;, &apos;91&apos;, &apos;98&apos;]
# </div>

# %%
#Ex:02: factorial 
a = 10
import math 
math.factorial(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">28</span><span class="ansired">]: </span>24
# </div>

# %%
#03 Create a dictionary : 
d =dict()
n = 6
for i in range(1,n+1):
    d[i]=i*i
print (d[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">36
# </div>
